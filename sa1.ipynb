# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import zscore

# %% [markdown]
# ### Pandas Series

# %%
# series from a list
data = [10, 20, 30, 40]
series_from_list = pd.Series(data)
print(series_from_list)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# series with specified index
series_with_index = pd.Series(data, index=['a', 'b', 'c', 'd'])
print(series_with_index)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
# series from a dict
data_dict = {'a': 10, 'b': 20, 'c': 30}
series_from_dict = pd.Series(data_dict)
print(series_from_dict)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# series from a scaler value and index
scalar_series = pd.Series(5, index=[0, 1, 2, 3])
print(scalar_series)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %% [markdown]
# ### Pandas DataFrame

# %%
# empty data frame
df_empty = pd.DataFrame()
print(df_empty)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# data frame using list
data_list = [10, 20, 30, 40]
df_list = pd.DataFrame(data_list, columns=['Numbers'])
df_list
# Out:
#    Numbers
# 0       10
# 1       20
# 2       30
# 3       40

# %%
# data frame using dict
data_dict = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35]
}
df_dict = pd.DataFrame(data_dict, index=[1,2,3])
df_dict
# Out:
#       Name  Age
# 1    Alice   25
# 2      Bob   30
# 3  Charlie   35

# %%
# data frame using a list of dicts
data_list_of_dicts = [
    {'Name': 'Alice', 'Age': 25},
    {'Name': 'Bob', 'Age': 30},
    {'Name': 'Charlie', 'Age': 35}
]
df_list_dict = pd.DataFrame(data_list_of_dicts)
df_list_dict
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
# data frame using a nested list
data_nested_list=[
    ["Alpha", "Gaurd", "A"],
    ["Beta", "Attack", "B"],
    ["Charlie", "Retrieve", "C"]
]
df_nested_list = pd.DataFrame(data_nested_list, columns=["Place", "Duty", "Notation"], index=[1,2,3])
df_nested_list
# Out:
#      Place      Duty Notation
# 1    Alpha     Gaurd        A
# 2     Beta    Attack        B
# 3  Charlie  Retrieve        C

# %% [markdown]
# ### Row and Column operation on DataFrame

# %%
# creating a data frame
data = {
    "Name" : ["Alpha", "Beta", "Charlie", "Delta", "Epsilon", "Fermi"],
    "Place" : ["India", "USA", "Russia", "China", "Japan", "Africa"],
    "Age" : [24, 26, 22, 29, 27, 21],
    "SubPlace" : ["Delhi", "NewYork", "Moscow", "Beijing", "Tokyo", "Cape Town"]
}
df = pd.DataFrame(data, index=['A','B','C','D','E','F'])
df
# Out:
#       Name   Place  Age   SubPlace
# A    Alpha   India   24      Delhi
# B     Beta     USA   26    NewYork
# C  Charlie  Russia   22     Moscow
# D    Delta   China   29    Beijing
# E  Epsilon   Japan   27      Tokyo
# F    Fermi  Africa   21  Cape Town

# %%
# drop a column
df.drop("SubPlace", axis=1, inplace=True)
df
# Out:
#       Name   Place  Age
# A    Alpha   India   24
# B     Beta     USA   26
# C  Charlie  Russia   22
# D    Delta   China   29
# E  Epsilon   Japan   27
# F    Fermi  Africa   21

# %%
# rename a column
df.rename(columns={"Place" : "Country"}, inplace=True)
df
# Out:
#       Name Country  Age
# A    Alpha   India   24
# B     Beta     USA   26
# C  Charlie  Russia   22
# D    Delta   China   29
# E  Epsilon   Japan   27
# F    Fermi  Africa   21

# %%
# insert a column
df.insert(3, "Status", ["Active"]*6)
df
# Out:
#       Name Country  Age  Status
# A    Alpha   India   24  Active
# B     Beta     USA   26  Active
# C  Charlie  Russia   22  Active
# D    Delta   China   29  Active
# E  Epsilon   Japan   27  Active
# F    Fermi  Africa   21  Active

# %%
# drop a row
df.drop('F', axis=0, inplace=True)
df
# Out:
#       Name Country  Age  Status
# A    Alpha   India   24  Active
# B     Beta     USA   26  Active
# C  Charlie  Russia   22  Active
# D    Delta   China   29  Active
# E  Epsilon   Japan   27  Active

# %%
# insert a row using loc
df.loc['G'] = ["Gamma", "Ukraine", 60, "Rogue"]
df
# Out:
#       Name  Country  Age  Status
# A    Alpha    India   24  Active
# B     Beta      USA   26  Active
# C  Charlie   Russia   22  Active
# D    Delta    China   29  Active
# E  Epsilon    Japan   27  Active
# G    Gamma  Ukraine   60   Rogue

# %%
# insert a row using concat
new_row = pd.DataFrame([["Iota", "Iraq", 43, "Missing"]], columns=df.columns, index=['I'])
df = pd.concat([df, new_row])
df
# Out:
#       Name Country  Age   Status
# A    Alpha   India   24   Active
# B     Beta     USA   26   Active
# C  Charlie  Russia   22   Active
# D    Delta   China   29   Active
# E  Epsilon   Japan   27   Active
# I     Iota    Iraq   43  Missing

# %%
# pop a column
status = pd.DataFrame(df.pop("Status"))
status
# Out:
#     Status
# A   Active
# B   Active
# C   Active
# D   Active
# E   Active
# I  Missing

# %% [markdown]
# ### Importing Data

# %%
# from a csv file
df_csv = pd.read_csv('#')

# from an excel file
df_excel = pd.read_excel('#')

# from a table
df_table = pd.read_table('#')

# from a sql table/database
df_sql = pd.read_sql("{query}", "{connection_object}")

# from a json file
df_json = pd.read_json("#")

# from a html file
df_html = pd.read_html("#")

# from clipboard
df_clipboard = pd.read_clipboard()

# from a dict
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35]
}
df_dict = pd.DataFrame(data)

# %% [markdown]
# ### Exporting Data

# %%
# to a csv file
df_csv.to_csv("#")

# to an excel file
df_excel.to_excel("#")

# to a sql table
df_sql.to_sql("{table_name}", "{connection_object}")

# to a json file
df_json.to_json("#")

# to a html file
df_html.to_html("#")

# to clipboard
df_clipboard.to_clipboard()

# %% [markdown]
# ### Indexing and Selecting Data

# %%
data = {
    "Name": ["Alpha", "Beta", "Charlie", "Delta", "Epsilon"],
    "Age": [24, 26, 22, 29, 27],
    "Country": ["India", "USA", "Russia", "China", "Japan"],
    "Status": ["Active", "Inactive", "Active", "Inactive", "Active"]
}
df = pd.DataFrame(data, index=['A','B','C','D','E'])
df
# Out:
#       Name  Age Country    Status
# A    Alpha   24   India    Active
# B     Beta   26     USA  Inactive
# C  Charlie   22  Russia    Active
# D    Delta   29   China  Inactive
# E  Epsilon   27   Japan    Active

# %%
# selecting using a column name
df['Name']
# Out:
# A      Alpha
# B       Beta
# C    Charlie
# D      Delta
# E    Epsilon
# Name: Name, dtype: object

# %%
# slecting multiple columns using list
df[["Name", "Age"]]
# Out:
#       Name  Age
# A    Alpha   24
# B     Beta   26
# C  Charlie   22
# D    Delta   29
# E  Epsilon   27

# %%
# filter method --> parameters: ["items", "like", "regex", "axis"]
item_filter = df.filter(items=["Name", "Age"])
item_filter
# Out:
#       Name  Age
# A    Alpha   24
# B     Beta   26
# C  Charlie   22
# D    Delta   29
# E  Epsilon   27

# %%
like_filter = df.filter(like='A', axis=0)
like_filter
# Out:
#     Name  Age Country  Status
# A  Alpha   24   India  Active

# %%
regex_filter = df.filter(regex=".*e$", axis=1)
regex_filter
# Out:
#       Name  Age
# A    Alpha   24
# B     Beta   26
# C  Charlie   22
# D    Delta   29
# E  Epsilon   27

# %%
# using loc --> Label Based Indexing
# by row label
row = df.loc["B"]
print(row)
# Out:
# Name           Beta
# Age              26
# Country         USA
# Status     Inactive
# Name: B, dtype: object

# %%
# by row and column label
row = df.loc["B", "Name"]
print(row)
# Out:
# Beta

# %%
# multiple rows and columns
output = df.loc[["B", "D"], ["Name", "Age"]]
print(output)
# Out:
#     Name  Age
# B   Beta   26
# D  Delta   29

# %%
# select all rows
output = df.loc[:, :]
print(output)
# Out:
#       Name  Age Country    Status
# A    Alpha   24   India    Active
# B     Beta   26     USA  Inactive
# C  Charlie   22  Russia    Active
# D    Delta   29   China  Inactive
# E  Epsilon   27   Japan    Active

# %%
# using iloc --> Integer location based indexing
#using row index
row = df.iloc[1]
print(row)
# Out:
# Name           Beta
# Age              26
# Country         USA
# Status     Inactive
# Name: B, dtype: object

# %%
# using both row and column index
output = df.iloc[0:2, 0:2]
print(output)
# Out:
#     Name  Age
# A  Alpha   24
# B   Beta   26

# %%
df.iat[1,2]
# Out:
# 'USA'

# %%
df.at['A','Name']
# Out:
# 'Alpha'

# %% [markdown]
# ### Subset Observations on Rows

# %%
data = {
    "Name": ["Alpha", "Beta", "Beta", "Delta", "Epsilon"],
    "Age": [24, 22, 22, 29, 27],
    "Country": ["India", "USA", "USA", "China", "Japan"],
    "Status": ["Active", "Inactive", "Inactive", "Inactive", "Active"]
}
df = pd.DataFrame(data)
filtered_df = df[df["Name"].str.len() > 4]
filtered_df
# Out:
#       Name  Age Country    Status
# 0    Alpha   24   India    Active
# 3    Delta   29   China  Inactive
# 4  Epsilon   27   Japan    Active

# %%
filtered_df= df.drop_duplicates()
filtered_df
# Out:
#       Name  Age Country    Status
# 0    Alpha   24   India    Active
# 1     Beta   22     USA  Inactive
# 3    Delta   29   China  Inactive
# 4  Epsilon   27   Japan    Active

# %%
df.sample(frac=0.5)
# Out:
#     Name  Age Country    Status
# 3  Delta   29   China  Inactive
# 0  Alpha   24   India    Active

# %%
df.sample(n=1)
# Out:
#     Name  Age Country    Status
# 3  Delta   29   China  Inactive

# %%
df.nlargest(1, "Age")
# Out:
#     Name  Age Country    Status
# 3  Delta   29   China  Inactive

# %%
df.nsmallest(1,"Age")
# Out:
#    Name  Age Country    Status
# 1  Beta   22     USA  Inactive

# %%
df.head(1)
# Out:
#     Name  Age Country  Status
# 0  Alpha   24   India  Active

# %%
df.tail(1)
# Out:
#       Name  Age Country  Status
# 4  Epsilon   27   Japan  Active

# %% [markdown]
# ### DataFrame Sorting

# %%
# creating a data frame
data = {
    "Name": ["Alpha", "Beta", "Charlie", "Delta", "Epsilon"],
    "Age": [24, 26, 22, 29, 27],
    "Country": ["India", "USA", "Russia", "China", "Japan"],
    "Status": ["Active", "Inactive", "Active", "Inactive", "Active"]
}
df = pd.DataFrame(data, index=['A','B','C','D','E'])

# %%
# sorting values by age in ascending order
df.sort_values(by="Age", ascending=False)
# Out:
#       Name  Age Country    Status
# D    Delta   29   China  Inactive
# E  Epsilon   27   Japan    Active
# B     Beta   26     USA  Inactive
# A    Alpha   24   India    Active
# C  Charlie   22  Russia    Active

# %%
# sort values by age in descending order
df.sort_values(by="Age", ascending=False)
# Out:
#       Name  Age Country    Status
# D    Delta   29   China  Inactive
# E  Epsilon   27   Japan    Active
# B     Beta   26     USA  Inactive
# A    Alpha   24   India    Active
# C  Charlie   22  Russia    Active

# %%
# sorting values by multiple features
df.sort_values(by=["Age", "Status"])
# Out:
#       Name  Age Country    Status
# C  Charlie   22  Russia    Active
# A    Alpha   24   India    Active
# B     Beta   26     USA  Inactive
# E  Epsilon   27   Japan    Active
# D    Delta   29   China  Inactive

# %%
# sort by row labels
df.sort_index()
# Out:
#       Name  Age Country    Status
# A    Alpha   24   India    Active
# B     Beta   26     USA  Inactive
# C  Charlie   22  Russia    Active
# D    Delta   29   China  Inactive
# E  Epsilon   27   Japan    Active

# %%
# sort by column labels
df.sort_index(axis=1)
# Out:
#    Age Country     Name    Status
# A   24   India    Alpha    Active
# B   26     USA     Beta  Inactive
# C   22  Russia  Charlie    Active
# D   29   China    Delta  Inactive
# E   27   Japan  Epsilon    Active

# %% [markdown]
# ### GroupBy

# %%
# creating a data frame
data = {
    "Name": ["Alpha", "Beta", "Charlie", "Delta", "Epsilon"],
    "Age": [24, 26, 22, 29, 27],
    "Country": ["India", "USA", "Russia", "China", "Japan"],
    "Status": ["Active", "Inactive", "Active", "Inactive", "Active"]
}
df = pd.DataFrame(data, index=['A','B','C','D','E'])

# %%
# groupby a single column
groupped_status = df.groupby("Status")
groupped_status

# %%
# groupby multiple columns
group1 = df.groupby(["Country", "Status"])
group1

# %%
# view groups
groupped_status.groups
# Out:
# {'Active': ['A', 'C', 'E'], 'Inactive': ['B', 'D']}

# %%
# get count per groups
groupped_status.count()
# Out:
#           Name  Age  Country
# Status
# Active       3    3        3
# Inactive     2    2        2

# %%
# get sum per group
groupped_status.sum()
# Out:
#                          Name  Age           Country
# Status
# Active    AlphaCharlieEpsilon   73  IndiaRussiaJapan
# Inactive            BetaDelta   55          USAChina

# %%
data = {
    "Department": ["HR", "IT", "HR", "Finance", "IT", "Finance", "HR"],
    "Employee": ["Alice", "Bob", "Carol", "David", "Eve", "Frank", "Grace"],
    "Salary": [50000, 60000, 52000, 70000, 65000, 72000, 51000],
    "Experience": [2, 3, 1, 5, 4, 6, 2]
}
df = pd.DataFrame(data)

# %%
# group the values based on department
grouped = df.groupby("Department")

# %%
# perform mean
grouped.mean(numeric_only=True)
# Out:
#              Salary  Experience
# Department
# Finance     71000.0    5.500000
# HR          51000.0    1.666667
# IT          62500.0    3.500000

# %%
# perform sum
grouped[["Salary", "Experience"]].sum()
# Out:
#             Salary  Experience
# Department
# Finance     142000          11
# HR          153000           5
# IT          125000           7

# %%
# get count for all features
grouped.count()
# Out:
#             Employee  Salary  Experience
# Department
# Finance            2       2           2
# HR                 3       3           3
# IT                 2       2           2

# %%
# find max in a group
grouped[["Salary", "Experience"]].max()
# Out:
#             Salary  Experience
# Department
# Finance      72000           6
# HR           52000           2
# IT           65000           4

# %%
# find min in a group
grouped[["Salary", "Experience"]].min()
# Out:
#             Salary  Experience
# Department
# Finance      70000           5
# HR           50000           1
# IT           60000           3

# %%
# custom aggregation
grouped.agg({
    "Salary": ["mean", "sum", "max", "min"],
    "Experience": ["mean", "max"]
})
# Out:
#              Salary                       Experience
#                mean     sum    max    min       mean max
# Department
# Finance     71000.0  142000  72000  70000   5.500000   6
# HR          51000.0  153000  52000  50000   1.666667   2
# IT          62500.0  125000  65000  60000   3.500000   4

# %% [markdown]
# ### Data Cleaning and Outlier Detection

# %%
# creating data frame from csv file
df = pd.read_csv("Loan_data.csv")
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# 1               3076               1500       126.0             360.0
# 2               5000               1800       208.0             360.0
# 3               2340               2546       100.0             360.0
# 4               3276                  0        78.0             360.0
# ..               ...                ...         ...               ...
# 362             4009               1777       113.0             360.0
# 363             4158                709       115.0             360.0
# 364             3250               1993       126.0             360.0
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History Property_Area
# 0               1.0         Urban
# 1               1.0         Urban
# 2               1.0         Urban
# 3               NaN         Urban
# 4               1.0         Urban
# ..              ...           ...
# 362             1.0         Urban
# 363             1.0         Urban
# 364             NaN     Semiurban
# 365             1.0         Rural
# 366             1.0         Rural
#
# [367 rows x 12 columns]

# %%
# display info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
df.shape
# Out:
# (367, 12)

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
# checking for null values
df.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 362    False   False    False       False      False          False
# 363    False   False    False       False      False          False
# 364    False   False    False       False      False          False
# 365    False   False    False       False      False          False
# 366    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False       False             False
# 1              False              False       False             False
# 2              False              False       False             False
# 3              False              False       False             False
# 4              False              False       False             False
# ..               ...                ...         ...               ...
# 362            False              False       False             False
# 363            False              False       False             False
# 364            False              False       False             False
# 365            False              False       False             False
# 366            False              False       False             False
#
#      Credit_History  Property_Area
# 0             False          False
# 1             False          False
# 2             False          False
# 3              True          False
# 4             False          False
# ..              ...            ...
# 362           False          False
# 363           False          False
# 364            True          False
# 365           False          False
# 366           False          False
#
# [367 rows x 12 columns]

# %%
# counting null values in each feature
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
# dropping the null values
dropped_df = df.dropna()
dropped_df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# 5    LP001054   Male     Yes          0  Not Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 361  LP002969   Male     Yes          1      Graduate            No
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# 1               3076               1500       126.0             360.0
# 2               5000               1800       208.0             360.0
# 4               3276                  0        78.0             360.0
# 5               2165               3422       152.0             360.0
# ..               ...                ...         ...               ...
# 361             2269               2167        99.0             360.0
# 362             4009               1777       113.0             360.0
# 363             4158                709       115.0             360.0
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History Property_Area
# 0               1.0         Urban
# 1               1.0         Urban
# 2               1.0         Urban
# 4               1.0         Urban
# 5               1.0         Urban
# ..              ...           ...
# 361             1.0     Semiurban
# 362             1.0         Urban
# 363             1.0         Urban
# 365             1.0         Rural
# 366             1.0         Rural
#
# [289 rows x 12 columns]

# %%
# filling the null values with 0
filled_df = df.fillna(0)
filled_df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# 1               3076               1500       126.0             360.0
# 2               5000               1800       208.0             360.0
# 3               2340               2546       100.0             360.0
# 4               3276                  0        78.0             360.0
# ..               ...                ...         ...               ...
# 362             4009               1777       113.0             360.0
# 363             4158                709       115.0             360.0
# 364             3250               1993       126.0             360.0
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History Property_Area
# 0               1.0         Urban
# 1               1.0         Urban
# 2               1.0         Urban
# 3               0.0         Urban
# 4               1.0         Urban
# ..              ...           ...
# 362             1.0         Urban
# 363             1.0         Urban
# 364             0.0     Semiurban
# 365             1.0         Rural
# 366             1.0         Rural
#
# [367 rows x 12 columns]

# %%
# filling null values using ffill method
ffilled_df = df.ffill()
ffilled_df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# 1               3076               1500       126.0             360.0
# 2               5000               1800       208.0             360.0
# 3               2340               2546       100.0             360.0
# 4               3276                  0        78.0             360.0
# ..               ...                ...         ...               ...
# 362             4009               1777       113.0             360.0
# 363             4158                709       115.0             360.0
# 364             3250               1993       126.0             360.0
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History Property_Area
# 0               1.0         Urban
# 1               1.0         Urban
# 2               1.0         Urban
# 3               1.0         Urban
# 4               1.0         Urban
# ..              ...           ...
# 362             1.0         Urban
# 363             1.0         Urban
# 364             1.0     Semiurban
# 365             1.0         Rural
# 366             1.0         Rural
#
# [367 rows x 12 columns]

# %%
# filling null values using bfill method
bfilled_df = df.bfill()
bfilled_df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# 1               3076               1500       126.0             360.0
# 2               5000               1800       208.0             360.0
# 3               2340               2546       100.0             360.0
# 4               3276                  0        78.0             360.0
# ..               ...                ...         ...               ...
# 362             4009               1777       113.0             360.0
# 363             4158                709       115.0             360.0
# 364             3250               1993       126.0             360.0
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History Property_Area
# 0               1.0         Urban
# 1               1.0         Urban
# 2               1.0         Urban
# 3               1.0         Urban
# 4               1.0         Urban
# ..              ...           ...
# 362             1.0         Urban
# 363             1.0         Urban
# 364             1.0     Semiurban
# 365             1.0         Rural
# 366             1.0         Rural
#
# [367 rows x 12 columns]

# %%
# filling null values with mean
new_df = df
new_df["LoanAmount"] = df["LoanAmount"].fillna(df["LoanAmount"].mean())
new_df["Loan_Amount_Term"] = df["Loan_Amount_Term"].fillna(df["Loan_Amount_Term"].mean())
new_df.isna().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
# creating a new data frame for outlier detection
age=[1,3,28,27,25,92,30,39,40,50,26,24,29,94]
af=pd.DataFrame(age)
af
# Out:
#      0
# 0    1
# 1    3
# 2   28
# 3   27
# 4   25
# 5   92
# 6   30
# 7   39
# 8   40
# 9   50
# 10  26
# 11  24
# 12  29
# 13  94

# %%
# using boxplot to detect outliers
sns.boxplot(data=af)
# Out:
# <Axes: >

# %%
# use iqr to remove outliers
Q1 = np.percentile(age, 25)
Q3 = np.percentile(age, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Quartile-1 : {Q1}")
print(f"Quartile-3 : {Q3}")
print(f"IQR : {IQR}")
print(f"Lower Bound : {lower_bound}")
print(f"Upper Bound : {upper_bound}")
# Out:
# Quartile-1 : 25.25
# Quartile-3 : 39.75
# IQR : 14.5
# Lower Bound : 3.5
# Upper Bound : 61.5

# %%
# remove outliers
af = af[(af >= lower_bound) & (af <= upper_bound)]

# %%
# perform boxplot to verify outlier removal
sns.boxplot(data=af)
# Out:
# <Axes: >

# %%
# creating data frame to perform z-score
data=[1,12,15,18,21,24,27,30,33,36,39,42,45,48,51,54,57,60,63,66,69,72,75,78,81,84,87,90,93,96,99,158]
df=pd.DataFrame(data)

# %%
# perform boxplot to detect outliers
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
# perform z-score method to detect outliers
z_score = np.abs(zscore(df))
threshold = 3

# %%
# remove outliers
outliers = df[z_score>3]
print(outliers)
cleaned_df = df[z_score<3]
print(cleaned_df)
# Out:
#         0
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
# 30    NaN
# 31  158.0
#        0
# 0    1.0
# 1   12.0
# 2   15.0
# 3   18.0
# 4   21.0
# 5   24.0
# 6   27.0
# 7   30.0
# 8   33.0
# 9   36.0
# 10  39.0
# 11  42.0
# 12  45.0
# 13  48.0
# 14  51.0
# 15  54.0
# 16  57.0
# 17  60.0
# 18  63.0
# 19  66.0
# 20  69.0
# 21  72.0
# 22  75.0
# 23  78.0
# 24  81.0
# 25  84.0
# 26  87.0
# 27  90.0
# 28  93.0
# 29  96.0
# 30  99.0
# 31   NaN

# %%
# perform boxplot to verify outlier removal
sns.boxplot(data=cleaned_df)
# Out:
# <Axes: >
